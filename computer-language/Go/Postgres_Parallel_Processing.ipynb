# %% [markdown]
# # **Parallel Processing**
#
# - PostgreSQL 9.6 부터 병렬 처리를 지원.
#
# - 병렬 처리는 Parallel Scan, Parallel Group by, Parallel Join을 지원.
#
# - ORACLE과 같은 생산자-소비자 모델은 아님.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Worker 프로세스 개수 산정 방식
#
# - Worker 프로세스의 개수는 min_parallel_relation_size 파라미터값을 기준으로 산정.
#
# - 기준 크기의 3배 단위로 1개씩 증가하며, 최대 7개.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Parallel Index Scan
#
# - PostgreSQL 10부터는 Parallel Index Scan 기능을 제공.
#
# - Parallel Index Scan 기능은 Index Full Scan 뿐만 아니라 Index Range Scan 시에도 동작.
#
# 1. 조건절 범위에 해당하는 "Start 리프 블록"과 "End 리프 블록"의 위치를 계산.
#
# 2. 처리 범위가 인덱스 병렬 처리를 할 정도로 큰지 확인.
#
# 3. 만일 크다면, 크기에 따라서 Worker 개수를 설정한 후에, "Start" ~ "End" 범위를 나눠서 처리.
#
# 4. 만일 작다면, 싱글 프로세스로 처리.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
