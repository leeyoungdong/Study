# %% [markdown]
# # **Amazon Kinesis Data Streams**

# %% [markdown]
# 특수 요구에 맞춰 스트리밍 데이터를 처리 또는 분석하는 사용자 지정 애플리케이션을 구축할 수 있다.
#
# 수십 만개의 소스에서 클릭 스트림, 애플리케이션 로그, 소셜 미디어와 같은 다양한 유형의 데이터를 Kinesis 데이터 스트림에 추가할 수 있으며 몇 초 안에 애플리케이션에서 스트림의 해당 데이터를 읽고 처리할 수 있다.
#
#
# 자동으로 수행하는 관리작업
#
#  - 데이터 처리량 수준에서 데이터를 스트리밍하는 데 필요한 인프라, 스토리지, 네트워킹, 구성을 관리한다.
#
#  - 하드웨어, 소프트웨어, 데이터 스트림을 위한 기타 서비스의 프로비저닝, 배포 혹은 지속적인 유지 관리 작업.
#
#  - 3곳의 가용 영역에 데이터를 동기적으로 복제하여 높은 가용성과 데이터 내구성을 제공한다.
#
#  - 용량을 자동으로 조정하므로 용량을 프로비저닝하고 관리할 필요가 없다.
#
#
# Amazon Kinesis Data Streams 기능
#
#  - 데이터를 데이터 생산자로부터 빠르게 이동한 다음 지속적으로 데이터를 처리하는 데 유용하다.
#
#   - 데이터 저장소로 전송하기 전에 데이터를 변환하거나, 실시간 지표 및 분석을 실행하거나, 추가 처리를 위해 더 복잡한 데이터 스트림을 파생하는 것을 의미함
#
#
# Amazon Kinesis Data Streams의 성능향상
#
#   - 샤드를 늘린다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Amazon Kinesis Data Firehose**

# %% [markdown]
# 스트리밍 ETL 솔루션. 스트리밍 데이터를 데이터 스토어와 분석 도구에 로드하는 가장 쉬운 방법
#
# 스트리밍 데이터를 캡처하고 변환한 후 Amazon S3, Amazon Redshift, Amazon OpenSearch Service 및 Splunk로 로드하여 이미 사용하고 있는 기존 비즈니스 인텔리전스 도구 및 대시보드를 통해 거의 실시간으로 분석할 수 있다.
#
# 데이터 처리량에 맞춰 자동으로 크기가 조정되며 지속적인 관리가 필요 없는 완전관리형 서비스이며, 데이터를 로드하기 전에 배치, 압축 및 암호화하여 대상 스토리지의 사용량을 최소화하고 보안을 강화할 수 있다.

# %% [markdown]
# **Kinesis Data Stream / Kinesis Data Firehose**

# %% [markdown]
# Kinesis Data Streams : 실시간으로 데이터를 수집 및 캡쳐
#
# Kinesis Data Firehose : 수집 및 캡쳐된 데이터를 분석 서비스로 로드 및 전송

# %% [markdown]
# ![image.png](data:image/png;base64,...)
