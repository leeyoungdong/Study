# %% [markdown]
# # **SVM은 왜 반대로 차원을 확장시키는 방식으로 동작할까? SVM은 왜 좋을까?**

# %% [markdown]
# **SVM(Support Vector Machine)**은 데이터가 사상된 공간에서 경계로 표현되며, 공간상에 존재하는 여러 경계 중 가장 큰 폭을 가진 경계를 찾는다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $B_1$: 결정 경계
#
# $b_{11}$: plus-plane
#
# $b_{12}$: minus-plane

# %% [markdown]
# # **SVM의 장단점**

# %% [markdown]
# **장점**
#
# - 분류와 회귀에 모두 사용할 수 있다.
# - 신경망 기법에 비해 과적합 정도가 낮다.
# - 예측의 정확도가 높다.
# - 저차원과 고차원 데이터에 대해서 모두 잘 작동
#
# **단점**
#
# - 데이터 전처리와 매개변수 설정에 따라 정확도가 달라질 수 있다.
# - 예측이 어떻게 이루어지는지에 대한 이해와 모델에 대한 해석이 어렵다.
# - 대용량 데이터에 대한 모델 구축 시 속도가 느리며, 메모리 할량이 크다.

# %% [markdown]
# **마진(Margin)**

# %% [markdown]
# - 마진(Margin)은 plus-plane과 minus-plane 사이의 거리를 의미하며, 최적의 결정 경계는 마진을 최대화.
# - SVM은 선형 분류뿐만 아니라 비선형 분류에도 사용되는데, 비선형 분류에서는 입력자료를 다차원 공간상으로 맵핑할 때 커널 트릭(kernel trick)을 사용하기도 한다.
# -  원공간(Input Space)의 데이터를 선형분류가 가능한 고차원 공간(Feature Space)으로 매핑한 뒤 두 범주를 분류하는 초평면을 찾는다. (Kernel-SVM)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **커널 트릭(Kernel Trick)**

# %% [markdown]
# - 커널 함수를 이용하여 차원 공간(low dimensional space)을 고차원 공간(high dimensional space)으로 매핑해주는 작업을 커널트릭이라 한다.
#
# **커널 함수의 종류**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
