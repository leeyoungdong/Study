# %% [markdown]
# # **Newton’s Method와 Gradient Descent**

# %% [markdown]
# **Newton's Method**

# %% [markdown]
# 함수 $f$의 2차 테일러 근사(quadratic approximation)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - $y$는 다음 스텝의 $x$ 값인 $x^+$이다. 또한 quadratic approximation을 $f_{approx}$로 정함
# - $f_{approx}$ 즉, quadratic approximation을 최소로 만드는 입력 $y$를 찾으려 함.
# - $f_{approx}$는 convex이므로 위 식의 gradient를 0으로 만드는 입력 $y$가 $f_{approx}$를 최소로 만들 것.
# - 결과가 Newton’s method에서의 step update 식이 된다.
# - 아래 식의 미분은 $y$에 대한 미분 임을 기억

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Gradient Descent**

# %% [markdown]
# Gradient descent에서는 함수 $f$의 2차 테일러 근사항을 사용하고, 2차 항의 경우 실제 2차 미분 결과가 아닌, 정방행렬(identity matrix)과 이를 $t$로 나눈 값으로 가정.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Newton’s method와 동일하게 위 근사식의 gradient가 0인 $y$ 값, 즉 $x^+$를 정할 수 있다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Newton's method와 Gradient descent의 step에 따른 수렴 방향 비교

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 파랑: Newton's method
# - 검정: Gradient descent

# %% [markdown]
# - Gradient descent는 2차 미분항을 정방행렬에 상수가 곱해진 값으로 가정하고 gradient를 계산하기 때문에, 등고선(contour)의 접선 방향에 수직하게(perpendicular) 수렴함을 확인할 수 있고, Newton’s method에 비해 느린 수렴 속도를 보임.
