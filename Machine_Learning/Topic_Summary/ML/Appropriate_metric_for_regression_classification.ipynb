# %% [markdown]
# # **회귀 / 분류시 알맞은 metric**

# %% [markdown]
# # **회귀**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **결정계수(Coefficient of determination)**는 (회귀선에 의해 설명되는 변동)/(전체 변동)을 말하며, 독립변수의 개수가 많아질수록 결정계수가 1에 가까워짐
# - 회귀모형이 높은 결정계수를 갖는다면 실제로 모형이 설명력이 높은 것인지 단순히 독립변수의 개수가 많은 것인지 알기 어려워 결정계수를 신뢰할 수 없게 되는 문제가 발생.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 수정된 결정계수는 결정계수의 문제를 해결하기 위해 표본의 크기(n)와 독립변수의 수(p)를 고려하여 수정된 결정계수를 계산

# %% [markdown]
# # **분류**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Log Loss** 혹은 **Binary Crossentropy**는 이진 분류에서의 지표로 사용

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Categorical Crossentropy**는 분류해야할 클래스가 3개 이상인 멀티 클래스 분류에서의 지표로 사용
