# %% [markdown]
# # **Weight Initialization**

# %% [markdown]
# 딥러닝에서 가중치를 잘 초기화하는 것은 기울기 소실이나 local minima 등의 문제를 야기할 수 있기 때문에 중요

# %% [markdown]
# # **LeCun Initialization**

# %% [markdown]
# 딥러닝의 대가 LeCun 교수님이 제시한 초기화 방법으로 들어오는 노드 수에 대해 정규 분포와 균등 분포를 따르는 방법이 있음

# %% [markdown]
# **정규 분포를 따르는 방법**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **균등 분포를 따르는 방법**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Xavier Initialization**

# %% [markdown]
# LeCun 방법과 비슷하지만 들어오는 노드 수와 나가는 노드 수에 의존하고, 적절한 상수값도 발견하여 사용한 방법

# %% [markdown]
# **정규 분포를 따르는 방법**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **균등 분포를 따르는 방법**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **He Initialization**

# %% [markdown]
# ReLU 와 함께 많이 사용되는 방법으로, LeCun 방법과 같지만 상수를 다르게 함. 들어오는 노드만 고려

# %% [markdown]
# **정규 분포를 따르는 방법**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **균등 분포를 따르는 방법**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
