# %% [markdown]
# # **머신러닝(machine)적 접근방법과 통계(statistics)적 접근방법의 둘간에 차이**

# %% [markdown]
# - 머신러닝적 접근방법과 통계적 접근방법의 차이는 두 방법의 주 목적이 다르다는 것
# - 머신러닝적 접근방법은 모델의 예측 성공률을 높이는게 목적
# - 모델의 신뢰도나 정교한 가정보다는 다양한 피쳐를 사용하여 (오버피팅을 감안하더라도) 높은 예측률을 달성하고자 한다.
# - 통계적 접근방법은 분포와 가정을 통해 신뢰 가능하고 정교한 모델을 만드는게 목적.
# - 모형을 복잡하지 않고 단순하게 만들고, 어떤 피쳐가 어떤 원인을 주는지 알 수 있도록 한다

# %% [markdown]
# # **인공신경망(deep learning이전의 전통적인)이 가지는 일반적인 문제점**

# %% [markdown]
# - 딥러닝 이전의 인공신경망은 선형적으로만 회귀, 분류를 수행하기 때문에 레이어를 깊게 쌓지 못함
# - XOR 문제 같은 복잡한 문제를 풀지 못하는 문제점이 있었음.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 시그모이드와 같은 비선형 함수를 선형 모델에 추가하여 XOR 문제를 해결하고, 편미분 체인룰을 사용한 오차역전파 방법으로 모델을 업데이트할 수 있게 되면서 레이어를 깊게 쌓은 딥러닝 인공신경망이 발전
