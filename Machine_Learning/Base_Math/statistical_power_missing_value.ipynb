# %% [markdown]
# # **검정력(statistical power)**

# %% [markdown]
# |Text | 귀무가설 H0 참 | 귀무가설 H0 참|
# |---|----|---|
# |귀무가설 H0채택 |옳은 결정(1-α) |제 2종 오류(β)|
# |귀무가설 H0기각 |제 1종 오류(α)|옳은 결정(1-β), 검정력|

# %% [markdown]
# - 검정력은 대립가설 H1이 참인 경우 귀무가설 H0를 기각(대립가설 H1을 채택)할 확률

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **missing value**

# %% [markdown]
# - 그대로 놔두기: 누락된 데이터를 그대로 놔두는 방법.
# - 삭제: 누락된 데이터를 제거하는 방법. 그러나 중요한 정보를 가진 데이터를 잃을 위험 존재.
# - 특정 값으로 채우기: 0, 빈번한 값, 지정한 상수값으로 채우기
# - 예측하여 채우기: K-means, 평균값, 중앙값으로 대체하는 것

# %% [markdown]
# - 1번 방법을 사용하여, 데이터가 누락된 채로 놔둔다고 가정.
#  -  일부 xgboost같은 알고리즘은 결측값을 고려하여 잘 학습한다.
#  - 결측치를 처리하는 로직이 없는 알고리즘(ex. sklearn의 LinearRegression)은 누락된 데이터 때문에 성능이 좋지 않을수 있음.
#  - 결론적으로 결측치를 처리해주어야함.
# - 2번 방법을 사용하여, 누락된 데이터를 제거한다고 가정.
#  - 제거하는 방법은 가장 쉬운 방법.
#  - 만약 100명 중 한명의 특징(feature)이 누락된 상태이므로, 해당 특징을 전부 삭제한다면 중요한 특성을 잃어버리는 결과를 초래.
# - 3번, 4번 방법을 사용하여 결측치를 채운다고 가정.
#  - 결측치를 채움으로서, 중요한 정보를 잃지않고 특성을 유지할 수 있다.
#  - 그러나 만약 100명 중 99명의 특징이 누락된 상태라고 한다면, 해당 특징을 어떠한 값으로 채우는 행위가 무의미.
#
# 따라서 결측치 상태나 비율, 어떤 모델을 사용할 것인지에 따라서 결측치 대응 방법이 달라질 수 있다.
